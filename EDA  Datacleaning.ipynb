# %%
import numpy as np
import pandas as pd
import requests
from bs4 import  BeautifulSoup
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Fortune Companies final")

# %%
df
# Out:
#      Unnamed: 0                              Company_Name        Country  \
# 0             0                            JPMorgan Chase  United States
# 1             1  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia
# 2             2                                      ICBC          China
# 3             3                   China Construction Bank          China
# 4             4                Agricultural Bank of China          China
# ..          ...                                       ...            ...
# 995         995                             Lufax Holding          China
# 996         996                              T&D Holdings          Japan
# 997         997                      Anta Sports Products          China
# 998         998                                   Moody's  United States
# 999         999                       Vestas Wind Systems        Denmark
#
#      Sales($B)  Profit($B)  Assets($B)  Market_Value($B)  Ranks Profit/Loss
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1000 non-null   int64
#  1   Company_Name      1000 non-null   object
#  2   Country           1000 non-null   object
#  3   Sales($B)         1000 non-null   float64
#  4   Profit($B)        1000 non-null   float64
#  5   Assets($B)        1000 non-null   float64
#  6   Market_Value($B)  1000 non-null   float64
#  7   Ranks             1000 non-null   int64
#  8   Profit/Loss       1000 non-null   object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 70.4+ KB

# %%
df['Sales($B)'].value_counts()
# Out:
# Sales($B)
# 10.84    3
# 8.44     3
# 10.90    3
# 16.84    3
# 10.33    3
#         ..
# 14.69    1
# 39.73    1
# 47.58    1
# 19.88    1
# 5.42     1
# Name: count, Length: 923, dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company_Name', 'Country', 'Sales($B)', 'Profit($B)',
#        'Assets($B)', 'Market_Value($B)', 'Ranks', 'Profit/Loss'],
#       dtype='object')

# %%
df.drop('Unnamed: 0',axis = 1,inplace = True)

# %%
df
# Out:
#                                  Company_Name        Country  Sales($B)  \
# 0                              JPMorgan Chase  United States     179.93
# 1    Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia     589.47
# 2                                        ICBC          China     216.77
# 3                     China Construction Bank          China     203.08
# 4                  Agricultural Bank of China          China     186.14
# ..                                        ...            ...        ...
# 995                             Lufax Holding          China       8.69
# 996                              T&D Holdings          Japan      18.83
# 997                      Anta Sports Products          China       7.97
# 998                                   Moody's  United States       5.42
# 999                       Vestas Wind Systems        Denmark      15.22
#
#      Profit($B)  Assets($B)  Market_Value($B)  Ranks Profit/Loss
# ...

# %%
df.shape
# Out:
# (1000, 8)

# %%
df
# Out:
#                                  Company_Name        Country  Sales($B)  \
# 0                              JPMorgan Chase  United States     179.93
# 1    Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia     589.47
# 2                                        ICBC          China     216.77
# 3                     China Construction Bank          China     203.08
# 4                  Agricultural Bank of China          China     186.14
# ..                                        ...            ...        ...
# 995                             Lufax Holding          China       8.69
# 996                              T&D Holdings          Japan      18.83
# 997                      Anta Sports Products          China       7.97
# 998                                   Moody's  United States       5.42
# 999                       Vestas Wind Systems        Denmark      15.22
#
#      Profit($B)  Assets($B)  Market_Value($B)  Ranks Profit/Loss
# ...

# %%
df.to_csv('Fortune companies final.csv',index = False)

# %%
df.describe()
# Out:
#          Sales($B)   Profit($B)   Assets($B)  Market_Value($B)        Ranks
# count  1000.000000  1000.000000  1000.000000       1000.000000  1000.000000
# mean     42.075711     3.993265   199.167950         62.512618   500.388000
# std      60.711597     8.654494   510.426468        157.110297   288.798102
# min    -109.990000   -23.110000     3.940000          0.287000     1.000000
# 25%      12.975000     1.190000    29.140000         15.425000   250.750000
# 50%      22.115000     2.100000    56.400000         30.165000   500.500000
# 75%      45.315000     4.172500   146.152500         56.392500   750.250000
# max     611.290000   156.360000  6116.820000       2746.210000  1000.000000

# %%
df['Ranks'].value_counts()
# Out:
# Ranks
# 620     3
# 878     3
# 579     3
# 167     3
# 663     3
#        ..
# 341     1
# 342     1
# 343     1
# 344     1
# 1000    1
# Name: count, Length: 893, dtype: int64

# %% [markdown]
# ## Null Values

# %%
df.isna().sum()
# Out:
# Company_Name        0
# Country             0
# Sales($B)           0
# Profit($B)          0
# Assets($B)          0
# Market_Value($B)    0
# Ranks               0
# Profit/Loss         0
# dtype: int64

# %% [markdown]
# ## Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Outliers

# %%
df.columns
# Out:
# Index(['Company_Name', 'Country', 'Sales($B)', 'Profit($B)', 'Assets($B)',
#        'Market_Value($B)', 'Ranks', 'Profit/Loss'],
#       dtype='object')

# %%
q1 = df['Sales($B)'].quantile(0.25)
q3 = df['Sales($B)'].quantile(0.75)
IQR = q3 - q1
Lower = q1-(1.5*IQR)
Upper = q3+(1.5*IQR)

# %%
Lower
# Out:
# -35.53499999999999

# %%
Upper
# Out:
# 93.82499999999999

# %%
df[(df['Sales($B)']>Upper) | (df['Sales($B)']<Lower)]
# Out:
#                                  Company_Name         Country  Sales($B)  \
# 0                              JPMorgan Chase   United States     179.93
# 1    Saudi Arabian Oil Company (Saudi Aramco)    Saudi Arabia     589.47
# 2                                        ICBC           China     216.77
# 3                     China Construction Bank           China     203.08
# 4                  Agricultural Bank of China           China     186.14
# ..                                        ...             ...        ...
# 539                                Indian Oil           India     103.42
# 616                     Legal & General Group  United Kingdom    -109.99
# 620                                        SK     South Korea     104.64
# 640                                Xiamen C&D           China     123.66
# 648                           Cardinal Health   United States     198.66
#
#      Profit($B)  Assets($B)  Market_Value($B)  Ranks Profit/Loss
# ...

# %%
q1 = df['Profit($B)'].quantile(0.25)
q3 = df['Profit($B)'].quantile(0.75)
IQR = q3 - q1
Lower = q1-(1.5*IQR)
Upper = q3+(1.5*IQR)

# %%
df[(df['Profit($B)']>Upper) | (df['Profit($B)']<Lower)]
# Out:
#                                  Company_Name        Country  Sales($B)  \
# 0                              JPMorgan Chase  United States     179.93
# 1    Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia     589.47
# 2                                        ICBC          China     216.77
# 3                     China Construction Bank          China     203.08
# 4                  Agricultural Bank of China          China     186.14
# ..                                        ...            ...        ...
# 580           Evergreen Marine Corp. (Taiwan)         Taiwan      21.04
# 654                                      Uber  United States      33.85
# 741       Fidelity National Information (FIS)  United States      14.55
# 747                      Korea Electric Power    South Korea      55.15
# 960                      Carnival Corporation  United States      14.98
#
#      Profit($B)  Assets($B)  Market_Value($B)  Ranks Profit/Loss
# ...

# %%
q1 = df['Assets($B)'].quantile(0.25)
q3 = df['Assets($B)'].quantile(0.75)
IQR = q3 - q1
Lower = q1-(1.5*IQR)
Upper = q3+(1.5*IQR)

# %%
df[(df['Assets($B)']>Upper) | (df['Assets($B)']<Lower)]
# Out:
#                                  Company_Name        Country  Sales($B)  \
# 0                              JPMorgan Chase  United States     179.93
# 1    Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia     589.47
# 2                                        ICBC          China     216.77
# 3                     China Construction Bank          China     203.08
# 4                  Agricultural Bank of China          China     186.14
# ..                                        ...            ...        ...
# 655                                    Nomura          Japan      18.35
# 688                               Danske Bank        Denmark      16.94
# 732                           Fubon Financial         Taiwan       9.76
# 822                           Resona Holdings          Japan       6.35
# 825                                     Aegon    Netherlands      20.07
#
#      Profit($B)  Assets($B)  Market_Value($B)  Ranks Profit/Loss
# ...

# %%
q1 = df['Market_Value($B)'].quantile(0.25)
q3 = df['Market_Value($B)'].quantile(0.75)
IQR = q3 - q1
Lower = q1-(1.5*IQR)
Upper = q3+(1.5*IQR)

# %%
df[(df['Market_Value($B)']>Upper) | (df['Market_Value($B)']<Lower)]
# Out:
#                                  Company_Name        Country  Sales($B)  \
# 0                              JPMorgan Chase  United States     179.93
# 1    Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia     589.47
# 2                                        ICBC          China     216.77
# 3                     China Construction Bank          China     203.08
# 4                  Agricultural Bank of China          China     186.14
# ..                                        ...            ...        ...
# 460                                  Prologis  United States       6.52
# 483                                    Intuit  United States      13.68
# 485                                Salesforce  United States      31.35
# 524                      Hermès International         France      12.19
# 567                    Advanced Micro Devices  United States      23.07
#
#      Profit($B)  Assets($B)  Market_Value($B)  Ranks Profit/Loss
# ...

# %%
q1 = df['Ranks'].quantile(0.25)
q3 = df['Ranks'].quantile(0.75)
IQR = q3 - q1
Lower = q1-(1.5*IQR)
Upper = q3+(1.5*IQR)

# %%
df[(df['Ranks']>Upper) | (df['Ranks']<Lower)]
# Out:
# Empty DataFrame
# Columns: [Company_Name, Country, Sales($B), Profit($B), Assets($B), Market_Value($B), Ranks, Profit/Loss]
# Index: []
